# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/semipro321/OneDrive/School/McGill/Research Projects/Essay/Data/birth_16/tab/ncds0123.tab', delimiter='\t')
# Out:
# /tmp/ipykernel_446314/3970479716.py:1: DtypeWarning: Columns (1,2,3,4,5,1756,1757,1758,1759,1760,1761,1762,1763,1764) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/semipro321/OneDrive/School/McGill/Research Projects/Essay/Data/birth_16/tab/ncds0123.tab', delimiter='\t')

# %%
df
# Out:
#         ncdsid n622 n0region n1region n2region n3region n553 n545 n520 n490  \
# 0      N10001N    2        9        9        9        9   23    4    2   12
# 1      N10002P    1        9        8        8        8   34    4    5    1
# 2      N10003Q    1        4        4        4        4   34    4   10    1
# 3      N10004R    2        1        1        1        1   26    4   11    1
# 4      N10005S    2       10       10       10       10   25    4    1    3
# ...        ...  ...      ...      ...      ...      ...  ...  ...  ...  ...
# 18549  N28554F    1       -2       -1        7        7
# 18550  N28555G    1        6        6        6        6   30    4    2    1
# 18551  N28556H    2        1        1        1        1   31    4    4    1
# 18552  N28557J    2        8        8        8       -1   28    4    3    8
# 18553  N28558K    2        3       -1        3        3   26    4    2    5
#
#        ... n1849            dvht07            dvht11            dvht16  \
# ...
